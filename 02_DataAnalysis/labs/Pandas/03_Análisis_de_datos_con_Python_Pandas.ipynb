# %%
import numpy as np
import pandas as pd
import datetime as dt

# %%
# importamos el dataset
df = pd.read_csv("https://raw.githubusercontent.com/stefmolin/Hands-On-Data-Analysis-with-Pandas-2nd-edition/2nd_edition/ch_02/data/earthquakes.csv",
                 sep=",", index_col=False)
df
# Out:
#      alert  ...                                                url
# 0      NaN  ...  https://earthquake.usgs.gov/earthquakes/eventp...
# 1      NaN  ...  https://earthquake.usgs.gov/earthquakes/eventp...
# 2      NaN  ...  https://earthquake.usgs.gov/earthquakes/eventp...
# 3      NaN  ...  https://earthquake.usgs.gov/earthquakes/eventp...
# 4      NaN  ...  https://earthquake.usgs.gov/earthquakes/eventp...
# ...    ...  ...                                                ...
# 9327   NaN  ...  https://earthquake.usgs.gov/earthquakes/eventp...
# 9328   NaN  ...  https://earthquake.usgs.gov/earthquakes/eventp...
# 9329   NaN  ...  https://earthquake.usgs.gov/earthquakes/eventp...
# 9330   NaN  ...  https://earthquake.usgs.gov/earthquakes/eventp...
# 9331   NaN  ...  https://earthquake.usgs.gov/earthquakes/eventp...
#
# [9332 rows x 26 columns]

# %% [markdown]
# ## Análisis del dataset

# %%
df.head()
# Out:
#   alert  cdi  ...        updated                                                url
# 0   NaN  NaN  ...  1539475395144  https://earthquake.usgs.gov/earthquakes/eventp...
# 1   NaN  NaN  ...  1539475253925  https://earthquake.usgs.gov/earthquakes/eventp...
# 2   NaN  4.4  ...  1539536756176  https://earthquake.usgs.gov/earthquakes/eventp...
# 3   NaN  NaN  ...  1539475196167  https://earthquake.usgs.gov/earthquakes/eventp...
# 4   NaN  NaN  ...  1539477547926  https://earthquake.usgs.gov/earthquakes/eventp...
#
# [5 rows x 26 columns]

# %%
df.tail()
# Out:
#      alert  ...                                                url
# 9327   NaN  ...  https://earthquake.usgs.gov/earthquakes/eventp...
# 9328   NaN  ...  https://earthquake.usgs.gov/earthquakes/eventp...
# 9329   NaN  ...  https://earthquake.usgs.gov/earthquakes/eventp...
# 9330   NaN  ...  https://earthquake.usgs.gov/earthquakes/eventp...
# 9331   NaN  ...  https://earthquake.usgs.gov/earthquakes/eventp...
#
# [5 rows x 26 columns]

# %%
df.head(10)
# Out:
#   alert  cdi  ...        updated                                                url
# 0   NaN  NaN  ...  1539475395144  https://earthquake.usgs.gov/earthquakes/eventp...
# 1   NaN  NaN  ...  1539475253925  https://earthquake.usgs.gov/earthquakes/eventp...
# 2   NaN  4.4  ...  1539536756176  https://earthquake.usgs.gov/earthquakes/eventp...
# 3   NaN  NaN  ...  1539475196167  https://earthquake.usgs.gov/earthquakes/eventp...
# 4   NaN  NaN  ...  1539477547926  https://earthquake.usgs.gov/earthquakes/eventp...
# 5   NaN  NaN  ...  1539500579236  https://earthquake.usgs.gov/earthquakes/eventp...
# 6   NaN  NaN  ...  1539473596465  https://earthquake.usgs.gov/earthquakes/eventp...
# 7   NaN  NaN  ...  1539476642808  https://earthquake.usgs.gov/earthquakes/eventp...
# 8   NaN  NaN  ...  1539475027632  https://earthquake.usgs.gov/earthquakes/eventp...
# 9   NaN  NaN  ...  1539473712040  https://earthquake.usgs.gov/earthquakes/eventp...
#
# [10 rows x 26 columns]

# %%
# Podemos analizar la forma del dataset (filas, columnas)
df.shape
# Out:
# (9332, 26)

# %%
# Podemos observar los atributos
df.columns
# Out:
# Index(['alert', 'cdi', 'code', 'detail', 'dmin', 'felt', 'gap', 'ids', 'mag',
#        'magType', 'mmi', 'net', 'nst', 'place', 'rms', 'sig', 'sources',
#        'status', 'time', 'title', 'tsunami', 'type', 'types', 'tz', 'updated',
#        'url'],
#       dtype='object')

# %%
# Si necesitamos realizar copia de seguridad
df_bak = df.to_csv('fichero_salida.csv', index=False)
df_bak

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
# Realizamos la prueba de subir el fichero.csv
pd.read_csv("/content/fichero_salida.csv")
# Out:
#      alert  ...                                                url
# 0      NaN  ...  https://earthquake.usgs.gov/earthquakes/eventp...
# 1      NaN  ...  https://earthquake.usgs.gov/earthquakes/eventp...
# 2      NaN  ...  https://earthquake.usgs.gov/earthquakes/eventp...
# 3      NaN  ...  https://earthquake.usgs.gov/earthquakes/eventp...
# 4      NaN  ...  https://earthquake.usgs.gov/earthquakes/eventp...
# ...    ...  ...                                                ...
# 9327   NaN  ...  https://earthquake.usgs.gov/earthquakes/eventp...
# 9328   NaN  ...  https://earthquake.usgs.gov/earthquakes/eventp...
# 9329   NaN  ...  https://earthquake.usgs.gov/earthquakes/eventp...
# 9330   NaN  ...  https://earthquake.usgs.gov/earthquakes/eventp...
# 9331   NaN  ...  https://earthquake.usgs.gov/earthquakes/eventp...
#
# [9332 rows x 26 columns]

# %%
# Comprobamos si el dataframe es vacío
df.empty
# Out:
# False

# %%
# Cuando observamos un dataframe verificamos que faltan columnas a observar o filas
df
# Out:
#      alert  ...                                                url
# 0      NaN  ...  https://earthquake.usgs.gov/earthquakes/eventp...
# 1      NaN  ...  https://earthquake.usgs.gov/earthquakes/eventp...
# 2      NaN  ...  https://earthquake.usgs.gov/earthquakes/eventp...
# 3      NaN  ...  https://earthquake.usgs.gov/earthquakes/eventp...
# 4      NaN  ...  https://earthquake.usgs.gov/earthquakes/eventp...
# ...    ...  ...                                                ...
# 9327   NaN  ...  https://earthquake.usgs.gov/earthquakes/eventp...
# 9328   NaN  ...  https://earthquake.usgs.gov/earthquakes/eventp...
# 9329   NaN  ...  https://earthquake.usgs.gov/earthquakes/eventp...
# 9330   NaN  ...  https://earthquake.usgs.gov/earthquakes/eventp...
# 9331   NaN  ...  https://earthquake.usgs.gov/earthquakes/eventp...
#
# [9332 rows x 26 columns]

# %% [markdown]
# Existen una opciones que nos permiten ampliar el margen del dataframe impreso.

# %%
pd.get_option('display.max_columns') # recoge la info de las columnas a mostrar
# Out:
# 0

# %%
pd.set_option('display.max_columns', 26)

# %%
df
# Out:
#      alert  cdi        code  \
# 0      NaN  NaN    37389218
# 1      NaN  NaN    37389202
# 2      NaN  4.4    37389194
# 3      NaN  NaN    37389186
# 4      NaN  NaN    73096941
# ...    ...  ...         ...
# 9327   NaN  NaN    73086771
# 9328   NaN  NaN    38063967
# 9329   NaN  NaN  2018261000
# 9330   NaN  NaN    38063959
# 9331   NaN  NaN    38063935
#
#                                                  detail      dmin  felt  \
# 0     https://earthquake.usgs.gov/fdsnws/event/1/que...  0.008693   NaN
# 1     https://earthquake.usgs.gov/fdsnws/event/1/que...  0.020030   NaN
# 2     https://earthquake.usgs.gov/fdsnws/event/1/que...  0.021370  28.0
# 3     https://earthquake.usgs.gov/fdsnws/event/1/que...  0.026180   NaN
# 4     https://earthquake.usgs.gov/fdsnws/event/1/que...  0.077990   NaN
# ...                                                 ...       ...   ...
# 9327  https://earthquake.usgs.gov/fdsnws/event/1/que...  0.018060   NaN
# ...

# %%
# Alternativa
pd.options.display.max_columns = 26

# %%
# Si quiero resetear esta opción
pd.reset_option('display.max_columns')

# %%
# Mostrará la guia
pd.describe_option('display')
# Out:
# display.chop_threshold : float or None
#     if set to a float value, all float values smaller then the given threshold
#     will be displayed as exactly 0 by repr and friends.
#     [default: None] [currently: None]
# display.colheader_justify : 'left'/'right'
#     Controls the justification of column headers. used by DataFrameFormatter.
#     [default: right] [currently: right]
# display.column_space No description available.
#     [default: 12] [currently: 12]
# display.date_dayfirst : boolean
#     When True, prints and parses dates with the day first, eg 20/01/2005
#     [default: False] [currently: False]
# display.date_yearfirst : boolean
#     When True, prints and parses dates with the year first, eg 2005/01/20
#     [default: False] [currently: False]
# display.encoding : str/unicode
#     Defaults to the detected encoding of the console.
#     Specifies the encoding to be used for strings returned by to_string,
# ...

# %%
# También nos interesa conocer los tipos de valores que contiene el df
df.dtypes
# Out:
# alert       object
# cdi        float64
# code        object
# detail      object
# dmin       float64
# felt       float64
# gap        float64
# ids         object
# mag        float64
# magType     object
# mmi        float64
# net         object
# nst        float64
# place       object
# rms        float64
# sig          int64
# sources     object
# status      object
# time         int64
# title       object
# tsunami      int64
# type        object
# types       object
# tz         float64
# updated      int64
# url         object
# dtype: object

# %%
# Recogemos informaciones adicionales
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9332 entries, 0 to 9331
# Data columns (total 26 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   alert    59 non-null     object
#  1   cdi      329 non-null    float64
#  2   code     9332 non-null   object
#  3   detail   9332 non-null   object
#  4   dmin     6139 non-null   float64
#  5   felt     329 non-null    float64
#  6   gap      6164 non-null   float64
#  7   ids      9332 non-null   object
#  8   mag      9331 non-null   float64
#  9   magType  9331 non-null   object
#  10  mmi      93 non-null     float64
#  11  net      9332 non-null   object
#  12  nst      5364 non-null   float64
#  13  place    9332 non-null   object
#  14  rms      9332 non-null   float64
#  15  sig      9332 non-null   int64
#  16  sources  9332 non-null   object
#  17  status   9332 non-null   object
#  18  time     9332 non-null   int64
#  19  title    9332 non-null   object
# ...

# %% [markdown]
# ## EDA (Exploratory Data Analysis) - primera parte

# %%
# mostrará un pequeño resumen de los estadísticos básicos
df.describe()
# Out:
#               cdi         dmin        felt          gap          mag  \
# count  329.000000  6139.000000  329.000000  6164.000000  9331.000000
# mean     2.754711     0.544925   12.310030   121.506588     1.497345
# std      1.010637     2.214305   48.954944    72.962363     1.203347
# min      0.000000     0.000648    0.000000    12.000000    -1.260000
# 25%      2.000000     0.020425    1.000000    66.142500     0.720000
# 50%      2.700000     0.059050    2.000000   105.000000     1.300000
# 75%      3.300000     0.177250    5.000000   159.000000     1.900000
# max      8.400000    53.737000  580.000000   355.910000     7.500000
#
#              mmi          nst          rms          sig          time  \
# count  93.000000  5364.000000  9332.000000  9332.000000  9.332000e+03
# mean    3.651398    19.053878     0.362122    56.899914  1.538284e+12
# std     1.790523    15.492315     0.317784    91.872163  6.080306e+08
# ...

# %%
# También podemos utilizar argumentos para formatear esta funciónç
df.describe(percentiles=[0.05, 0.95])
# Out:
#               cdi         dmin        felt          gap          mag  \
# count  329.000000  6139.000000  329.000000  6164.000000  9331.000000
# mean     2.754711     0.544925   12.310030   121.506588     1.497345
# std      1.010637     2.214305   48.954944    72.962363     1.203347
# min      0.000000     0.000648    0.000000    12.000000    -1.260000
# 5%       2.000000     0.005491    1.000000    35.000000    -0.040000
# 50%      2.700000     0.059050    2.000000   105.000000     1.300000
# 95%      4.300000     2.678900   40.200000   276.000000     4.400000
# max      8.400000    53.737000  580.000000   355.910000     7.500000
#
#              mmi          nst          rms          sig          time  \
# count  93.000000  5364.000000  9332.000000  9332.000000  9.332000e+03
# mean    3.651398    19.053878     0.362122    56.899914  1.538284e+12
# std     1.790523    15.492315     0.317784    91.872163  6.080306e+08
# ...

# %%
df.describe(include=np.object)
# Out:
#         alert      code                                             detail  \
# count      59      9332                                               9332
# unique      2      9332                                               9332
# top     green  37388954  https://earthquake.usgs.gov/fdsnws/event/1/que...
# freq       58         1                                                  1
#
#                  ids magType   net                   place sources    status  \
# count           9332    9331  9332                    9332    9332      9332
# unique          9332      10    14                    5433      52         2
# top     ,ci37371074,      ml    ak  10km NE of Aguanga, CA    ,ak,  reviewed
# freq               1    6803  3166                     306    2981      7797
#
#                                  title        type  \
# count                             9332        9332
# unique                            7807           5
# ...

# %%
# Directamente podemos utilizar el argumento include='all' para incluir todos los atributos
df.describe(include='all')
# Out:
#         alert         cdi      code  \
# count      59  329.000000      9332
# unique      2         NaN      9332
# top     green         NaN  37388954
# freq       58         NaN         1
# mean      NaN    2.754711       NaN
# std       NaN    1.010637       NaN
# min       NaN    0.000000       NaN
# 25%       NaN    2.000000       NaN
# 50%       NaN    2.700000       NaN
# 75%       NaN    3.300000       NaN
# max       NaN    8.400000       NaN
#
#                                                    detail         dmin  \
# count                                                9332  6139.000000
# unique                                               9332          NaN
# top     https://earthquake.usgs.gov/fdsnws/event/1/que...          NaN
# freq                                                    1          NaN
# mean                                                  NaN     0.544925
# std                                                   NaN     2.214305
# ...

# %%
# Si deseamos conocer los estadísticos de una sola feature
df.rms.describe()
# Out:
# count    9332.000000
# mean        0.362122
# std         0.317784
# min         0.000000
# 25%         0.119675
# 50%         0.210000
# 75%         0.590000
# max         1.910000
# Name: rms, dtype: float64

# %%
# Es lo mismo que realziar esta operación: dataframe['nombre atributo']
df['rms'].describe()
# Out:
# count    9332.000000
# mean        0.362122
# std         0.317784
# min         0.000000
# 25%         0.119675
# 50%         0.210000
# 75%         0.590000
# max         1.910000
# Name: rms, dtype: float64

# %% [markdown]
# ### Investigamos por cada una de las features o atributo

# %%
type(df.rms)
# Out:
# pandas.core.series.Series

# %%
df.rms.count()
# Out:
# 9332

# %%
df.rms.nunique()
# Out:
# 823

# %%
df.rms.idxmin()
# Out:
# 1044

# %%
df.alert.nunique() # contabiliza los valores únicos
# Out:
# 2

# %%
df.alert.unique() #identifica un array con los valores únicos
# Out:
# array([nan, 'green', 'red'], dtype=object)

# %%
# Si necesitamos contar y agrupar por valores únicos
df.alert.value_counts()
# Out:
# green    58
# red       1
# Name: alert, dtype: int64

# %%
df.rms.value_counts()
# Out:
# 0.1200    253
# 0.1300    250
# 0.0300    247
# 0.1500    228
# 0.0400    223
#          ...
# 0.0999      1
# 0.1171      1
# 0.1275      1
# 0.1771      1
# 0.0882      1
# Name: rms, Length: 823, dtype: int64

# %% [markdown]
# ## Subset de un dataframe
#
# Es obtener un dataframe más pequeño de n columnas

# %%
df.mag # obtenemos los valores de un solo atributo
# Out:
# 0       1.35
# 1       1.29
# 2       3.42
# 3       0.44
# 4       2.16
#         ...
# 9327    0.62
# 9328    1.00
# 9329    2.40
# 9330    1.10
# 9331    0.66
# Name: mag, Length: 9332, dtype: float64

# %%
df['mag'] # es lo mismo que el anterior
# Out:
# 0       1.35
# 1       1.29
# 2       3.42
# 3       0.44
# 4       2.16
#         ...
# 9327    0.62
# 9328    1.00
# 9329    2.40
# 9330    1.10
# 9331    0.66
# Name: mag, Length: 9332, dtype: float64

# %%
df[['mag','alert','title']]
# Out:
#        mag alert                                     title
# 0     1.35   NaN             M 1.4 - 9km NE of Aguanga, CA
# 1     1.29   NaN             M 1.3 - 9km NE of Aguanga, CA
# 2     3.42   NaN             M 3.4 - 8km NE of Aguanga, CA
# 3     0.44   NaN             M 0.4 - 9km NE of Aguanga, CA
# 4     2.16   NaN             M 2.2 - 10km NW of Avenal, CA
# ...    ...   ...                                       ...
# 9327  0.62   NaN      M 0.6 - 9km ENE of Mammoth Lakes, CA
# 9328  1.00   NaN               M 1.0 - 3km W of Julian, CA
# 9329  2.40   NaN  M 2.4 - 35km NNE of Hatillo, Puerto Rico
# 9330  1.10   NaN             M 1.1 - 9km NE of Aguanga, CA
# 9331  0.66   NaN             M 0.7 - 9km NE of Aguanga, CA
#
# [9332 rows x 3 columns]

# %%
# Un resultado similar al anterior es declarar primero las columnas y luego visualizarlas
columnas = ['mag','title','alert']
df[columnas]
# Out:
#        mag                                     title alert
# 0     1.35             M 1.4 - 9km NE of Aguanga, CA   NaN
# 1     1.29             M 1.3 - 9km NE of Aguanga, CA   NaN
# 2     3.42             M 3.4 - 8km NE of Aguanga, CA   NaN
# 3     0.44             M 0.4 - 9km NE of Aguanga, CA   NaN
# 4     2.16             M 2.2 - 10km NW of Avenal, CA   NaN
# ...    ...                                       ...   ...
# 9327  0.62      M 0.6 - 9km ENE of Mammoth Lakes, CA   NaN
# 9328  1.00               M 1.0 - 3km W of Julian, CA   NaN
# 9329  2.40  M 2.4 - 35km NNE of Hatillo, Puerto Rico   NaN
# 9330  1.10             M 1.1 - 9km NE of Aguanga, CA   NaN
# 9331  0.66             M 0.7 - 9km NE of Aguanga, CA   NaN
#
# [9332 rows x 3 columns]

# %%
# También podemos utilizar list comprehension
df[
   ['title','alert'] +
   [col for col in df.columns if col.startswith('mag')]
]
# Out:
#                                          title alert   mag magType
# 0                M 1.4 - 9km NE of Aguanga, CA   NaN  1.35      ml
# 1                M 1.3 - 9km NE of Aguanga, CA   NaN  1.29      ml
# 2                M 3.4 - 8km NE of Aguanga, CA   NaN  3.42      ml
# 3                M 0.4 - 9km NE of Aguanga, CA   NaN  0.44      ml
# 4                M 2.2 - 10km NW of Avenal, CA   NaN  2.16      md
# ...                                        ...   ...   ...     ...
# 9327      M 0.6 - 9km ENE of Mammoth Lakes, CA   NaN  0.62      md
# 9328               M 1.0 - 3km W of Julian, CA   NaN  1.00      ml
# 9329  M 2.4 - 35km NNE of Hatillo, Puerto Rico   NaN  2.40      md
# 9330             M 1.1 - 9km NE of Aguanga, CA   NaN  1.10      ml
# 9331             M 0.7 - 9km NE of Aguanga, CA   NaN  0.66      ml
#
# [9332 rows x 4 columns]

# %%
# Para poder analizar la list comprehension separamos las columnas obtenidas
[col for col in df.columns if col.startswith('mag')]
# Out:
# ['mag', 'magType']

# %%
['title','time'] \ # este es un separador de líneas
+ [col for col in df.columns if col.startswith('mag')] # el resultado obtenido
# Out:
# ['title', 'time', 'mag', 'magType']

# %%
# Realizamos operaciones de slicing
df[10:100] # puedo visualizar las filas desde el índice 10 hasta el 99 (100-1)
# Out:
#    alert  cdi        code                                             detail  \
# 10   NaN  NaN    37389162  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 11   NaN  NaN  2018286010  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 12   NaN  NaN    37389146  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 13   NaN  NaN    1000hbti  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 14   NaN  NaN    73096921  https://earthquake.usgs.gov/fdsnws/event/1/que...
# ..   ...  ...         ...                                                ...
# 95   NaN  NaN    73096766  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 96   NaN  NaN    00660828  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 97   NaN  NaN    20280318  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 98   NaN  NaN    20280314  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 99   NaN  NaN    20280313  https://earthquake.usgs.gov/fdsnws/event/1/que...
#
# ...

# %%
df[['title','mag']][10:100] # obtenemos la visualización de las dos columnas y solo 90 filas
# Out:
#                                                 title   mag
# 10                     M 0.5 - 10km NE of Aguanga, CA  0.50
# 11  M 2.8 - 53km SE of Punta Cana, Dominican Republic  2.77
# 12                      M 0.5 - 9km NE of Aguanga, CA  0.50
# 13         M 4.5 - 120km SSW of Banda Aceh, Indonesia  4.50
# 14                   M 2.1 - 14km NW of Parkfield, CA  2.13
# ..                                                ...   ...
# 95                 M 1.6 - 3km NNE of The Geysers, CA  1.57
# 96             M 0.9 - 60km E of Big Pine, California  0.90
# 97               M 1.3 - 45km WSW of Big Lake, Alaska  1.30
# 98                M 1.8 - 66km SW of Cantwell, Alaska  1.80
# 99        M 1.6 - 112km NNW of Arctic Village, Alaska  1.60
#
# [90 rows x 2 columns]

# %%
df[columnas][10:100] # también podemos obtenerlo de esta forma
# Out:
#      mag                                              title alert
# 10  0.50                     M 0.5 - 10km NE of Aguanga, CA   NaN
# 11  2.77  M 2.8 - 53km SE of Punta Cana, Dominican Republic   NaN
# 12  0.50                      M 0.5 - 9km NE of Aguanga, CA   NaN
# 13  4.50         M 4.5 - 120km SSW of Banda Aceh, Indonesia   NaN
# 14  2.13                   M 2.1 - 14km NW of Parkfield, CA   NaN
# ..   ...                                                ...   ...
# 95  1.57                 M 1.6 - 3km NNE of The Geysers, CA   NaN
# 96  0.90             M 0.9 - 60km E of Big Pine, California   NaN
# 97  1.30               M 1.3 - 45km WSW of Big Lake, Alaska   NaN
# 98  1.80                M 1.8 - 66km SW of Cantwell, Alaska   NaN
# 99  1.60        M 1.6 - 112km NNW of Arctic Village, Alaska   NaN
#
# [90 rows x 3 columns]

# %%
# El orden no importa
df[10:100][columnas].equals(df[columnas][10:100])
# Out:
# True

# %% [markdown]
# ## Indexing: Realizar subset con índices

# %%
# la función loc() utilizará los nombres
x = df.loc[10:99, 'title']
x
# Out:
# 10                       M 0.5 - 10km NE of Aguanga, CA
# 11    M 2.8 - 53km SE of Punta Cana, Dominican Republic
# 12                        M 0.5 - 9km NE of Aguanga, CA
# 13           M 4.5 - 120km SSW of Banda Aceh, Indonesia
# 14                     M 2.1 - 14km NW of Parkfield, CA
#                             ...
# 95                   M 1.6 - 3km NNE of The Geysers, CA
# 96               M 0.9 - 60km E of Big Pine, California
# 97                 M 1.3 - 45km WSW of Big Lake, Alaska
# 98                  M 1.8 - 66km SW of Cantwell, Alaska
# 99          M 1.6 - 112km NNW of Arctic Village, Alaska
# Name: title, Length: 90, dtype: object

# %%
type(x) # el valor obtenido es un conjunto de Series
# Out:
# pandas.core.series.Series

# %%
df.loc[110:112, 'title'] = df.loc[110:112, 'title'].str.lower()
df.loc[110:112, 'title']
# Out:
# 110               m 1.1 - 35km s of ester, alaska
# 111    m 1.9 - 93km wnw of arctic village, alaska
# 112      m 0.9 - 20km wsw of smith valley, nevada
# Name: title, dtype: object

# %%
df.loc[:,'mag']
# Out:
# 0       1.35
# 1       1.29
# 2       3.42
# 3       0.44
# 4       2.16
#         ...
# 9327    0.62
# 9328    1.00
# 9329    2.40
# 9330    1.10
# 9331    0.66
# Name: mag, Length: 9332, dtype: float64

# %%
df.loc[10:15, ['title','mag','time']]
# Out:
#                                                 title   mag           time
# 10                     M 0.5 - 10km NE of Aguanga, CA  0.50  1539471831030
# 11  M 2.8 - 53km SE of Punta Cana, Dominican Republic  2.77  1539471621260
# 12                      M 0.5 - 9km NE of Aguanga, CA  0.50  1539470934710
# 13         M 4.5 - 120km SSW of Banda Aceh, Indonesia  4.50  1539470898340
# 14                   M 2.1 - 14km NW of Parkfield, CA  2.13  1539470851950
# 15       M 2.0 - 156km WNW of Haines Junction, Canada  2.00  1539470304219

# %%
# es lo mismo que 
df.loc[10:15, columnas]
# Out:
#      mag                                              title alert
# 10  0.50                     M 0.5 - 10km NE of Aguanga, CA   NaN
# 11  2.77  M 2.8 - 53km SE of Punta Cana, Dominican Republic   NaN
# 12  0.50                      M 0.5 - 9km NE of Aguanga, CA   NaN
# 13  4.50         M 4.5 - 120km SSW of Banda Aceh, Indonesia   NaN
# 14  2.13                   M 2.1 - 14km NW of Parkfield, CA   NaN
# 15  2.00       M 2.0 - 156km WNW of Haines Junction, Canada   NaN

# %%
# con iloc() realizamos la operación por posición
df.iloc[10:15, [19,8]] # columnas 19 y 8
# Out:
#                                                 title   mag
# 10                     M 0.5 - 10km NE of Aguanga, CA  0.50
# 11  M 2.8 - 53km SE of Punta Cana, Dominican Republic  2.77
# 12                      M 0.5 - 9km NE of Aguanga, CA  0.50
# 13         M 4.5 - 120km SSW of Banda Aceh, Indonesia  4.50
# 14                   M 2.1 - 14km NW of Parkfield, CA  2.13

# %%
df.iloc[10:15, 6:10] # slice de columnas
# Out:
#       gap             ids   mag magType
# 10   57.0    ,ci37389162,  0.50      ml
# 11  186.0  ,pr2018286010,  2.77      md
# 12   76.0    ,ci37389146,  0.50      ml
# 13  157.0    ,us1000hbti,  4.50      mb
# 14   71.0    ,nc73096921,  2.13      md

# %%
# Si queremos evaluar iloc y loc
df.iloc[10:15, 6:10].equals(
    df.loc[10:14, 'gap':'magType']
)
# Out:
# True

# %% [markdown]
# ## Uso de filtros

# %%
df.mag > 3
# Out:
# 0       False
# 1       False
# 2        True
# 3       False
# 4       False
#         ...
# 9327    False
# 9328    False
# 9329    False
# 9330    False
# 9331    False
# Name: mag, Length: 9332, dtype: bool

# %%
# Si necesitamos solo visualizar los resultados basada en una condición
df[df.mag >= 7.]
# Out:
#       alert  cdi      code                                             detail  \
# 837   green  4.1  1000haa3  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 5263    red  8.4  1000h3p4  https://earthquake.usgs.gov/fdsnws/event/1/que...
#
#        dmin  felt   gap                                 ids  mag magType  \
# 837   1.763   3.0  14.0  ,us1000haa3,pt18283003,at00pgehsk,  7.0     mww
# 5263  1.589  18.0  27.0             ,us1000h3p4,us1000h4p4,  7.5     mww
#
#        mmi net  nst                               place   rms   sig  \
# 837   7.46  us  NaN  117km E of Kimbe, Papua New Guinea  1.22   755
# 5263  9.12  us  NaN           78km N of Palu, Indonesia  1.27  2015
#
#          sources    status           time  \
# 837   ,us,pt,at,  reviewed  1539204500290
# 5263     ,us,us,  reviewed  1538128963480
#
#                                            title  tsunami        type  \
# 837   M 7.0 - 117km E of Kimbe, Papua New Guinea        1  earthquake
# ...

# %%
# También podemos obtenerlo con loc
df.loc[
       df.mag >= 7.,
       ['alert','mag','magType','title','type']
]
# Out:
#       alert  mag magType                                       title  \
# 837   green  7.0     mww  M 7.0 - 117km E of Kimbe, Papua New Guinea
# 5263    red  7.5     mww           M 7.5 - 78km N of Palu, Indonesia
#
#             type
# 837   earthquake
# 5263  earthquake

# %%
# Alternamos con multiples condiciones AND y OR
df.loc[
       (df.tsunami == 1) & (df.alert == 'red'),
       ['alert','mag','magType','title','type','tsunami','time']
]
# Out:
#      alert  mag magType                              title        type  \
# 5263   red  7.5     mww  M 7.5 - 78km N of Palu, Indonesia  earthquake
#
#       tsunami           time
# 5263        1  1538128963480

# %%
df.loc[
       (df.tsunami == 1) | (df.alert == 'red'),
       ['alert','mag','magType','title','tsunami','type']
]
# Out:
#       alert  mag magType                                              title  \
# 36      NaN  5.0     mww  M 5.0 - 165km NNW of Flying Fish Cove, Christm...
# 118   green  6.7     mww            M 6.7 - 262km NW of Ozernovskiy, Russia
# 501   green  5.6     mww        M 5.6 - 128km SE of Kimbe, Papua New Guinea
# 799   green  6.5     mww         M 6.5 - 148km S of Severo-Kuril'sk, Russia
# 816   green  6.2     mww        M 6.2 - 94km SW of Kokopo, Papua New Guinea
# ...     ...  ...     ...                                                ...
# 8561    NaN  5.4      mb         M 5.4 - 228km S of Taron, Papua New Guinea
# 8624    NaN  5.1      mb       M 5.1 - 278km SE of Pondaguitan, Philippines
# 9133  green  5.1      ml               M 5.1 - 64km SSW of Kaktovik, Alaska
# 9175    NaN  5.2      mb                M 5.2 - 126km N of Dili, East Timor
# 9304    NaN  5.1      mb   M 5.1 - 34km NW of Finschhafen, Papua New Guinea
#
#       tsunami        type
# 36          1  earthquake
# ...

# %%
# podemos crear subset con filtros notnull e isnull()
df.loc[
       (df.place.str.contains('Alaska')) & (df.alert.notnull()),
       ['alert','mag','magType','title','tsunami','type']
]
# Out:
#       alert  mag magType                                        title  \
# 1015  green  5.0      ml     M 5.0 - 61km SSW of Chignik Lake, Alaska
# 1273  green  4.0      ml          M 4.0 - 71km SW of Kaktovik, Alaska
# 1795  green  4.0      ml           M 4.0 - 60km WNW of Valdez, Alaska
# 2752  green  4.0      ml         M 4.0 - 67km SSW of Kaktovik, Alaska
# 3260  green  3.9      ml       M 3.9 - 44km N of North Nenana, Alaska
# 4101  green  4.2      ml  M 4.2 - 131km NNW of Arctic Village, Alaska
# 6897  green  3.8      ml         M 3.8 - 80km SSW of Kaktovik, Alaska
# 8524  green  3.8      ml         M 3.8 - 69km SSW of Kaktovik, Alaska
# 9133  green  5.1      ml         M 5.1 - 64km SSW of Kaktovik, Alaska
#
#       tsunami        type
# 1015        1  earthquake
# 1273        1  earthquake
# 1795        1  earthquake
# 2752        1  earthquake
# 3260        0  earthquake
# 4101        0  earthquake
# 6897        0  earthquake
# 8524        0  earthquake
# ...

# %%
# Puedo realizar también filtros por búsqueda de patrones, RegEx o expresión regular
df.loc[
      (df.place.str.contains(r'CA|California$|CALIFORNIA')) & (df.mag > 3.8),
       ['alert','mag','magType','title','tsunami','type']
]
# Out:
#       alert   mag magType                              title  tsunami  \
# 1465  green  3.83      mw  M 3.8 - 109km WNW of Trinidad, CA        0
# 2414  green  3.83      mw   M 3.8 - 5km SW of Tres Pinos, CA        1
#
#             type
# 1465  earthquake
# 2414  earthquake

# %%
# uso del between
df.loc[
       df.mag.between(6.5, 7.5),
       ['alert','mag','magType','title','tsunami','type']
]
# Out:
#       alert  mag magType                                       title  tsunami  \
# 118   green  6.7     mww     M 6.7 - 262km NW of Ozernovskiy, Russia        1
# 799   green  6.5     mww  M 6.5 - 148km S of Severo-Kuril'sk, Russia        1
# 837   green  7.0     mww  M 7.0 - 117km E of Kimbe, Papua New Guinea        1
# 4363  green  6.7     mww      M 6.7 - 263km NNE of Ndoi Island, Fiji        1
# 5263    red  7.5     mww           M 7.5 - 78km N of Palu, Indonesia        1
#
#             type
# 118   earthquake
# 799   earthquake
# 837   earthquake
# 4363  earthquake
# 5263  earthquake

# %%
# También podemos filtrar por isin()
df.loc[
       df.magType.isin(['mw','mwb']),
       ['alert','mag','magType','title','tsunami','type']
]
# Out:
#       alert   mag magType                                   title  tsunami  \
# 995     NaN  3.35      mw             M 3.4 - 9km WNW of Cobb, CA        0
# 1465  green  3.83      mw       M 3.8 - 109km WNW of Trinidad, CA        0
# 2414  green  3.83      mw        M 3.8 - 5km SW of Tres Pinos, CA        1
# 4988  green  4.41      mw       M 4.4 - 1km SE of Delta, B.C., MX        1
# 6307  green  5.80     mwb  M 5.8 - 297km NNE of Ndoi Island, Fiji        0
# 8257  green  5.70     mwb      M 5.7 - 175km SSE of Lambasa, Fiji        0
#
#             type
# 995   earthquake
# 1465  earthquake
# 2414  earthquake
# 4988  earthquake
# 6307  earthquake
# 8257  earthquake

# %%
# Podemos filtrar por índice máximo e índice mínimo
indices = [df.mag.idxmin(), df.mag.idxmax()]
indices
# Out:
# [2409, 5263]

# %%
df.loc[
       indices,
       ['alert','mag','magType','title','tsunami','type']
]
# Out:
#      alert   mag magType                              title  tsunami  \
# 2409   NaN -1.26      ml  M -1.3 - 41km ENE of Adak, Alaska        0
# 5263   red  7.50     mww  M 7.5 - 78km N of Palu, Indonesia        1
#
#             type
# 2409  earthquake
# 5263  earthquake

# %%
# Qué pasaría si utilizara el filter()
df.filter(items=['mag','magType']).head()
# Out:
#     mag magType
# 0  1.35      ml
# 1  1.29      ml
# 2  3.42      ml
# 3  0.44      ml
# 4  2.16      md

# %%
df.filter(like='mag').head()
# Out:
#     mag magType
# 0  1.35      ml
# 1  1.29      ml
# 2  3.42      ml
# 3  0.44      ml
# 4  2.16      md

# %%
# utilizamos filter y regex
df.filter(regex=r'^t').head()
# Out:
#             time                          title  tsunami        type  \
# 0  1539475168010  M 1.4 - 9km NE of Aguanga, CA        0  earthquake
# 1  1539475129610  M 1.3 - 9km NE of Aguanga, CA        0  earthquake
# 2  1539475062610  M 3.4 - 8km NE of Aguanga, CA        0  earthquake
# 3  1539474978070  M 0.4 - 9km NE of Aguanga, CA        0  earthquake
# 4  1539474716050  M 2.2 - 10km NW of Avenal, CA        0  earthquake
#
#                                                types     tz
# 0         ,geoserve,nearby-cities,origin,phase-data, -480.0
# 1         ,geoserve,nearby-cities,origin,phase-data, -480.0
# 2  ,dyfi,focal-mechanism,geoserve,nearby-cities,o... -480.0
# 3         ,geoserve,nearby-cities,origin,phase-data, -480.0
# 4  ,geoserve,nearby-cities,origin,phase-data,scit... -480.0

# %%
# Si utilizamos filter() y axis
X = df.set_index('place').filter(like='Japan', axis=0).filter(
    items=['mag','magType','title']
).head()
X
# Out:
#                              mag magType                                title
# place
# 160km NNW of Nago, Japan     4.6      mb     M 4.6 - 160km NNW of Nago, Japan
# 7km ESE of Asahi, Japan      5.2     mww      M 5.2 - 7km ESE of Asahi, Japan
# 14km E of Tomakomai, Japan   4.5     mwr   M 4.5 - 14km E of Tomakomai, Japan
# 139km WSW of Naze, Japan     4.7      mb     M 4.7 - 139km WSW of Naze, Japan
# 53km ESE of Kamaishi, Japan  4.6      mb  M 4.6 - 53km ESE of Kamaishi, Japan

# %%
type(X)
# Out:
# pandas.core.frame.DataFrame

# %%
Y = df.set_index('place').title.filter(like='Japan').head()
Y
# Out:
# place
# 160km NNW of Nago, Japan          M 4.6 - 160km NNW of Nago, Japan
# 7km ESE of Asahi, Japan            M 5.2 - 7km ESE of Asahi, Japan
# 14km E of Tomakomai, Japan      M 4.5 - 14km E of Tomakomai, Japan
# 139km WSW of Naze, Japan          M 4.7 - 139km WSW of Naze, Japan
# 53km ESE of Kamaishi, Japan    M 4.6 - 53km ESE of Kamaishi, Japan
# Name: title, dtype: object

# %%
type(Y)
# Out:
# pandas.core.series.Series

# %% [markdown]
# ## Añadir y quitar datos

# %%
# Podemos realizar una carga de datos parciales
df = pd.read_csv("https://raw.githubusercontent.com/stefmolin/Hands-On-Data-Analysis-with-Pandas-2nd-edition/2nd_edition/ch_02/data/earthquakes.csv",
                 usecols=['time','title','place','magType',
                          'mag','alert','type','tsunami'])
df
# Out:
#      alert   mag magType                             place           time  \
# 0      NaN  1.35      ml             9km NE of Aguanga, CA  1539475168010
# 1      NaN  1.29      ml             9km NE of Aguanga, CA  1539475129610
# 2      NaN  3.42      ml             8km NE of Aguanga, CA  1539475062610
# 3      NaN  0.44      ml             9km NE of Aguanga, CA  1539474978070
# 4      NaN  2.16      md             10km NW of Avenal, CA  1539474716050
# ...    ...   ...     ...                               ...            ...
# 9327   NaN  0.62      md      9km ENE of Mammoth Lakes, CA  1537230228060
# 9328   NaN  1.00      ml               3km W of Julian, CA  1537230135130
# 9329   NaN  2.40      md  35km NNE of Hatillo, Puerto Rico  1537229908180
# 9330   NaN  1.10      ml             9km NE of Aguanga, CA  1537229545350
# 9331   NaN  0.66      ml             9km NE of Aguanga, CA  1537228864470
#
#                                          title  tsunami        type
# ...

# %%
# Podemos crear un nuevo atributo vacío o con valores por defecto
df['source'] = 'USGS API'

# %%
df.head(10)
# Out:
#   alert   mag magType                                       place  \
# 0   NaN  1.35      ml                       9km NE of Aguanga, CA
# 1   NaN  1.29      ml                       9km NE of Aguanga, CA
# 2   NaN  3.42      ml                       8km NE of Aguanga, CA
# 3   NaN  0.44      ml                       9km NE of Aguanga, CA
# 4   NaN  2.16      md                       10km NW of Avenal, CA
# 5   NaN  2.61      md  55km ESE of Punta Cana, Dominican Republic
# 6   NaN  1.70      ml                105km W of Talkeetna, Alaska
# 7   NaN  1.13      md                    10km NW of Parkfield, CA
# 8   NaN  0.92      md                   6km NW of The Geysers, CA
# 9   NaN  4.70      mb             219km SSE of Saparua, Indonesia
#
#             time                                              title  tsunami  \
# 0  1539475168010                      M 1.4 - 9km NE of Aguanga, CA        0
# 1  1539475129610                      M 1.3 - 9km NE of Aguanga, CA        0
# ...

# %%
df.mag < 0
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 9327    False
# 9328    False
# 9329    False
# 9330    False
# 9331    False
# Name: mag, Length: 9332, dtype: bool

# %%
# Creamos un nuevo atributo con una condición del atributo mag < 0
df['mag_negative'] = df.mag < 0
df
# Out:
#      alert   mag magType                             place           time  \
# 0      NaN  1.35      ml             9km NE of Aguanga, CA  1539475168010
# 1      NaN  1.29      ml             9km NE of Aguanga, CA  1539475129610
# 2      NaN  3.42      ml             8km NE of Aguanga, CA  1539475062610
# 3      NaN  0.44      ml             9km NE of Aguanga, CA  1539474978070
# 4      NaN  2.16      md             10km NW of Avenal, CA  1539474716050
# ...    ...   ...     ...                               ...            ...
# 9327   NaN  0.62      md      9km ENE of Mammoth Lakes, CA  1537230228060
# 9328   NaN  1.00      ml               3km W of Julian, CA  1537230135130
# 9329   NaN  2.40      md  35km NNE of Hatillo, Puerto Rico  1537229908180
# 9330   NaN  1.10      ml             9km NE of Aguanga, CA  1537229545350
# 9331   NaN  0.66      ml             9km NE of Aguanga, CA  1537228864470
#
#                                          title  tsunami        type    source  \
# ...

# %%
df[df.mag < 0] # realizamos un subset para visualizar la condición anterior
# Out:
#      alert   mag magType                             place           time  \
# 39     NaN -0.10      ml   6km NW of Lemmon Valley, Nevada  1539458844506
# 49     NaN -0.10      ml   6km NW of Lemmon Valley, Nevada  1539455017464
# 135    NaN -0.40      ml        10km SSE of Beatty, Nevada  1539422175717
# 161    NaN -0.02      md        20km SSE of Ronan, Montana  1539412475360
# 198    NaN -0.20      ml         60km N of Pahrump, Nevada  1539398340822
# ...    ...   ...     ...                               ...            ...
# 9202   NaN -0.11      ml          42km ENE of Adak, Alaska  1537257741590
# 9241   NaN -0.69      ml          42km ENE of Adak, Alaska  1537249710450
# 9261   NaN -0.02      ml      28km S of Morton, Washington  1537245303560
# 9267   NaN -0.32      md  30km ENE of Seeley Lake, Montana  1537244570780
# 9305   NaN -0.27      ml  49km W of Tanaga Volcano, Alaska  1537235444640
#
#                                           title  tsunami        type  \
# ...

# %%
df[df.mag < 0].describe()
# Out:
#               mag          time  tsunami
# count  491.000000  4.910000e+02    491.0
# mean    -0.339593  1.538237e+12      0.0
# std      0.252297  5.649134e+08      0.0
# min     -1.260000  1.537235e+12      0.0
# 25%     -0.500000  1.537815e+12      0.0
# 50%     -0.300000  1.538154e+12      0.0
# 75%     -0.130000  1.538687e+12      0.0
# max     -0.010000  1.539459e+12      0.0

# %%
# Operamos con las expresiones regulares
df.place.str.extract(r', (.*$)')[0].sort_values().unique()
# Out:
# array(['Afghanistan', 'Alaska', 'Argentina', 'Arizona', 'Arkansas',
#        'Australia', 'Azerbaijan', 'B.C., MX', 'Barbuda', 'Bolivia',
#        'Bonaire, Saint Eustatius and Saba ', 'British Virgin Islands',
#        'Burma', 'CA', 'California', 'Canada', 'Chile', 'China',
#        'Christmas Island', 'Colombia', 'Colorado', 'Costa Rica',
#        'Dominican Republic', 'East Timor', 'Ecuador', 'Ecuador region',
#        'El Salvador', 'Fiji', 'Greece', 'Greenland', 'Guam', 'Guatemala',
#        'Haiti', 'Hawaii', 'Honduras', 'Idaho', 'Illinois', 'India',
#        'Indonesia', 'Iran', 'Iraq', 'Italy', 'Jamaica', 'Japan', 'Kansas',
#        'Kentucky', 'Kyrgyzstan', 'Martinique', 'Mauritius', 'Mayotte',
#        'Mexico', 'Missouri', 'Montana', 'NV', 'Nevada', 'New Caledonia',
#        'New Hampshire', 'New Mexico', 'New Zealand', 'Nicaragua',
#        'North Carolina', 'Northern Mariana Islands', 'Oklahoma', 'Oregon',
#        'Pakistan', 'Papua New Guinea', 'Peru', 'Philippines',
# ...

# %%
# Operamos con transformación de unos valores
df['parsed_place'] = df.place.str.replace(
    r'.* of ', '', regex=True # elimina cualquier elemento que tenga of
).str.replace(
    'the ', '' # eliminamos el the
).str.replace(
    r'CA$', 'California', regex=True
).str.replace(
    r'NV$', 'Nevada', regex=True
).str.replace(
    r'MX$', 'Mexico', regex=True
).str.replace(
    r' region$', '', regex=True
).str.replace(
    'Fiji Islands', 'Fiji'
).str.replace(
    r'^.*, ', '', regex=True # elimina cualquier cosa rara que encuentra al principio del texto
).str.strip() # elimina cualquier espacio

# %%
df.parsed_place.sort_values().unique()
# Out:
# array(['Afghanistan', 'Alaska', 'Argentina', 'Arizona', 'Arkansas',
#        'Ascension Island', 'Australia', 'Azerbaijan', 'Balleny Islands',
#        'Barbuda', 'Bolivia', 'British Virgin Islands', 'Burma',
#        'California', 'Canada', 'Carlsberg Ridge',
#        'Central East Pacific Rise', 'Central Mid-Atlantic Ridge', 'Chile',
#        'China', 'Christmas Island', 'Colombia', 'Colorado', 'Costa Rica',
#        'Dominican Republic', 'East Timor', 'Ecuador', 'El Salvador',
#        'Fiji', 'Greece', 'Greenland', 'Guam', 'Guatemala', 'Haiti',
#        'Hawaii', 'Honduras', 'Idaho', 'Illinois', 'India',
#        'Indian Ocean Triple Junction', 'Indonesia', 'Iran', 'Iraq',
#        'Italy', 'Jamaica', 'Japan', 'Kansas', 'Kentucky',
#        'Kermadec Islands', 'Kuril Islands', 'Kyrgyzstan', 'Martinique',
#        'Mauritius', 'Mayotte', 'Mexico', 'Mid-Indian Ridge', 'Missouri',
#        'Montana', 'Nevada', 'New Caledonia', 'New Hampshire',
# ...

# %%
# una válida alternativa es utilizar assign()
df.assign(
    in_ca=df.parsed_place.str.endswith('California'),
    in_alaska=df.parsed_place.str.endswith('Alaska')).sample(5, random_state=0)
# Out:
#      alert   mag magType                               place           time  \
# 7207   NaN  4.80     mwr    73km SSW of Masachapa, Nicaragua  1537749595210
# 4755   NaN  1.09      ml    28km NNW of Packwood, Washington  1538227540460
# 4595   NaN  1.80      ml        77km SSW of Kaktovik, Alaska  1538259609862
# 3566   NaN  1.50      ml  102km NW of Arctic Village, Alaska  1538464751822
# 2182   NaN  0.90      ml         26km ENE of Pine Valley, CA  1538801713880
#
#                                            title  tsunami        type  \
# 7207    M 4.8 - 73km SSW of Masachapa, Nicaragua        0  earthquake
# 4755    M 1.1 - 28km NNW of Packwood, Washington        0  earthquake
# 4595        M 1.8 - 77km SSW of Kaktovik, Alaska        0  earthquake
# 3566  M 1.5 - 102km NW of Arctic Village, Alaska        0  earthquake
# 2182         M 0.9 - 26km ENE of Pine Valley, CA        0  earthquake
#
#         source  mag_negative parsed_place  in_ca  in_alaska
# ...

# %%
# También podemos hacer uso de la función lambda()
df.assign(
    in_ca=df.parsed_place == 'California',
    in_alaska=df.parsed_place == 'Alaska',
    neither=lambda x: ~x.in_ca & ~x.in_alaska
).sample(5, random_state=0)
# Out:
#      alert   mag magType                               place           time  \
# 7207   NaN  4.80     mwr    73km SSW of Masachapa, Nicaragua  1537749595210
# 4755   NaN  1.09      ml    28km NNW of Packwood, Washington  1538227540460
# 4595   NaN  1.80      ml        77km SSW of Kaktovik, Alaska  1538259609862
# 3566   NaN  1.50      ml  102km NW of Arctic Village, Alaska  1538464751822
# 2182   NaN  0.90      ml         26km ENE of Pine Valley, CA  1538801713880
#
#                                            title  tsunami        type  \
# 7207    M 4.8 - 73km SSW of Masachapa, Nicaragua        0  earthquake
# 4755    M 1.1 - 28km NNW of Packwood, Washington        0  earthquake
# 4595        M 1.8 - 77km SSW of Kaktovik, Alaska        0  earthquake
# 3566  M 1.5 - 102km NW of Arctic Village, Alaska        0  earthquake
# 2182         M 0.9 - 26km ENE of Pine Valley, CA        0  earthquake
#
#         source  mag_negative parsed_place  in_ca  in_alaska  neither
# ...

# %%
# Podemos realizar filtros y concatenar
tsunami = df[df.tsunami == 1]
no_tsunami = df[df.tsunami == 0]
tsunami.shape, no_tsunami.shape
# Out:
# ((61, 11), (9271, 11))

# %%
# Concatenar
pd.concat([tsunami, no_tsunami]).shape
# Out:
# (9332, 11)

# %%
# Otra forma de realizarlo es con append()
tsunami.append(no_tsunami).shape
# Out:
# (9332, 11)

# %%
type(tsunami.append(no_tsunami))
# Out:
# pandas.core.frame.DataFrame
