# %% [markdown]
# # Librerías Matplotlib
#
# - https://matplotlib.org/stable/gallery/index.html

# %%
# Cargamos las librerías de visualización
import matplotlib.pyplot as plt
import seaborn as sns

# Librerías de análisis de datos
import numpy as np
import pandas as pd

# %% [markdown]
# ## Representar las funciones de coseno y seno a la vez

# %%
x = np.arange(-2*np.pi, 2*np.pi, 0.1)

# %%
x
# Out:
# array([-6.28318531, -6.18318531, -6.08318531, -5.98318531, -5.88318531,
#        -5.78318531, -5.68318531, -5.58318531, -5.48318531, -5.38318531,
#        -5.28318531, -5.18318531, -5.08318531, -4.98318531, -4.88318531,
#        -4.78318531, -4.68318531, -4.58318531, -4.48318531, -4.38318531,
#        -4.28318531, -4.18318531, -4.08318531, -3.98318531, -3.88318531,
#        -3.78318531, -3.68318531, -3.58318531, -3.48318531, -3.38318531,
#        -3.28318531, -3.18318531, -3.08318531, -2.98318531, -2.88318531,
#        -2.78318531, -2.68318531, -2.58318531, -2.48318531, -2.38318531,
#        -2.28318531, -2.18318531, -2.08318531, -1.98318531, -1.88318531,
#        -1.78318531, -1.68318531, -1.58318531, -1.48318531, -1.38318531,
#        -1.28318531, -1.18318531, -1.08318531, -0.98318531, -0.88318531,
#        -0.78318531, -0.68318531, -0.58318531, -0.48318531, -0.38318531,
#        -0.28318531, -0.18318531, -0.08318531,  0.01681469,  0.11681469,
# ...

# %%
# visualización
plt.plot(x, np.cos(x))

# añadimos etiquetas y título
plt.xlabel("x")
plt.ylabel("cos(x)")

# Mostramos los resultados
plt.show()

# %%
#representación de seno y coseno cambiando el tipo de línea
plt.plot(x, np.cos(x), 'r+',x, np.sin(x),'bo') # red plus - blue dot
plt.xlabel("x = cos(x)")
plt.ylabel("y = sin(x)")
plt.legend()
plt.show()
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# # Histogramas

# %%
# Parámetros de la función gaussiana
mu, sigma = 50, 7

# generamos un array
x = mu + sigma * np.random.randn(10000)

# la función hist() calcula la frecuencia y el número de barras
n, bins, patches = plt.hist(x, 30, density=1,
                           facecolor='dodgerblue',
                           alpha=0.5)
plt.xlabel('x')
plt.ylabel('Probabilidad')
plt.text(20, .025, r'$\mu=50,\ \sigma=7$')

# Controlamos el tamaño de los ejes (xmin, xmax, ymin, ymax)
plt.axis([10, 90, 0, 0.07])

# Mostramos el grid
plt.grid(True)

# Mostramos el resultado
plt.show()

# %% [markdown]
# ## Countplot

# %%
# Cargamos un dataset
penguins = sns.load_dataset("penguins")
penguins.shape
# Out:
# (344, 7)

# %%
type(penguins)
# Out:
# pandas.core.frame.DataFrame

# %%
penguins.head()
# Out:
#   species     island  bill_length_mm  ...  flipper_length_mm  body_mass_g     sex
# 0  Adelie  Torgersen            39.1  ...              181.0       3750.0    Male
# 1  Adelie  Torgersen            39.5  ...              186.0       3800.0  Female
# 2  Adelie  Torgersen            40.3  ...              195.0       3250.0  Female
# 3  Adelie  Torgersen             NaN  ...                NaN          NaN     NaN
# 4  Adelie  Torgersen            36.7  ...              193.0       3450.0  Female
#
# [5 rows x 7 columns]

# %%
sns.countplot(x=penguins.species)

# %% [markdown]
# `palette` permite configurar la paleta de colores

# %%
sns.countplot(x=penguins.island, palette="Reds")

# %%
sns.countplot(x=penguins.sex, palette="Set3")

# %%
sns.countplot(y= penguins.island, palette="Blues") # invertimos el eje

# %%
titanic = sns.load_dataset("titanic")
titanic.shape
# Out:
# (891, 15)

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  ...  deck  embark_town  alive  alone
# 0         0       3    male  22.0  ...   NaN  Southampton     no  False
# 1         1       1  female  38.0  ...     C    Cherbourg    yes  False
# 2         1       3  female  26.0  ...   NaN  Southampton    yes   True
# 3         1       1  female  35.0  ...     C  Southampton    yes  False
# 4         0       3    male  35.0  ...   NaN  Southampton     no   True
#
# [5 rows x 15 columns]

# %%
titanic.deck.nunique()
# Out:
# 7

# %%
titanic = pd.read_csv("https://raw.githubusercontent.com/marcusRB/The_Bridge_School_DataScience_PT/main/02_DataAnalysis/dataset/titanic.csv")

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 0            1         0       3  ...   7.2500   NaN         S
# 1            2         1       1  ...  71.2833   C85         C
# 2            3         1       3  ...   7.9250   NaN         S
# 3            4         1       1  ...  53.1000  C123         S
# 4            5         0       3  ...   8.0500   NaN         S
#
# [5 rows x 12 columns]

# %%
titanic.Cabin.nunique()
# Out:
# 147

# %%
sns.countplot(y=titanic.Cabin, palette="Blues")

# %%
titanic.Cabin.value_counts()
# Out:
# B96 B98        4
# G6             4
# C23 C25 C27    4
# E101           3
# D              3
#               ..
# D50            1
# D47            1
# A6             1
# C95            1
# B39            1
# Name: Cabin, Length: 147, dtype: int64

# %%
sns.catplot(x="Cabin", y="Survived", data=titanic, kind="bar", ci=None)

# %%
# podemos crear un nuevo atributo InCabin que nos permite conocer si el pasajero estaba en cabina o no
titanic['InCabin'] = ~titanic['Cabin'].isnull()
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  ... Cabin Embarked  InCabin
# 0            1         0       3  ...   NaN        S    False
# 1            2         1       1  ...   C85        C     True
# 2            3         1       3  ...   NaN        S    False
# 3            4         1       1  ...  C123        S     True
# 4            5         0       3  ...   NaN        S    False
#
# [5 rows x 13 columns]

# %%
titanic.Cabin.isnull().sum()/len(titanic.Cabin)*100
# Out:
# 77.10437710437711

# %%
sns.barplot(x="InCabin", y="Survived", data=titanic)
plt.show()

# %% [markdown]
# `hue` argumento que permite apilar / agrupar las categorías con otra

# %%
sns.countplot(x=titanic.Pclass, hue=titanic.Sex, palette='light:#5A9')

# %%
sns.countplot(x=titanic.Sex, hue=titanic.Survived, palette='ch:s=.25,rot=-.25')

# %%
sns.countplot(x=titanic.Pclass, hue=titanic.Sex, palette='flare', dodge=False) # dodge me permite apilar

# %%
sns.countplot(x=penguins.island, hue=penguins.species)

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  ... Cabin Embarked  InCabin
# 0            1         0       3  ...   NaN        S    False
# 1            2         1       1  ...   C85        C     True
# 2            3         1       3  ...   NaN        S    False
# 3            4         1       1  ...  C123        S     True
# 4            5         0       3  ...   NaN        S    False
#
# [5 rows x 13 columns]

# %%
sns.distplot(titanic['Fare'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
from scipy.stats import norm, skew
sns.distplot(np.log1p(titanic.Fare),fit=norm)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
# Procedemos con la tarea de agrupación
titanic['FareGroup'] = pd.qcut(titanic['Fare'], 6, labels=['A','B','C','D','E','F'])

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  ... Embarked InCabin  FareGroup
# 0            1         0       3  ...        S   False          A
# 1            2         1       1  ...        C    True          D
# 2            3         1       3  ...        S   False          B
# 3            4         1       1  ...        S    True          D
# 4            5         0       3  ...        S   False          B
#
# [5 rows x 14 columns]

# %%
titanic[['FareGroup','Survived']].groupby(['FareGroup'], as_index=False).mean()
# Out:
#   FareGroup  Survived
# 0         A  0.205128
# 1         B  0.190789
# 2         C  0.366906
# 3         D  0.436242
# 4         E  0.417808
# 5         F  0.697987

# %%
sns.barplot(x='FareGroup',y='Survived', data=titanic)

# %%
titanic.Age.describe()
# Out:
# count    714.000000
# mean      29.699118
# std       14.526497
# min        0.420000
# 25%       20.125000
# 50%       28.000000
# 75%       38.000000
# max       80.000000
# Name: Age, dtype: float64

# %%
# representación en barra de la age y survived
sns.countplot(y=titanic.Age, palette="Blues")

# %%
titanic.Age.nunique()
# Out:
# 88

# %%
sns.barplot(x="Age",y="Survived",data=titanic)

# %%
sns.distplot(titanic.Age, fit=norm)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ### Agrupaciones con pd.qcut() y pd.cut()

# %%
# Creamos una agrupación en n grupos con pd.qcut()
titanic['AgeGroup_qcut'] = pd.qcut(titanic.Age, 5, labels=['A','B','C','D','E'])

# %%
sns.barplot(x='AgeGroup_qcut',y='Survived', data=titanic)

# %%
# creamos una agrupación en n grupos con pd.cut()
bins = [-np.inf, 12, 24, 35, 60, np.inf]
labels = ['Unknow', 'Teenager', 'YoungAdult', 'Adult', 'Senior']
titanic['Age'] = titanic['Age'].fillna(-0.5) # imputamos -0.5 a los valores nulos
titanic['AgeGroup_cut'] = pd.cut(titanic.Age, bins, labels = labels)

# %%
sns.barplot(x="AgeGroup_cut", y='Survived', data=titanic)

# %%
# también un extremo
bins = [-1, 0, 5, 12, 18, 24, 35, 60, np.inf]
labels = ['Unknown', 'Baby', 'Child', 'Teenager', 'Student', 'Young Adult', 'Adult', 'Senior']
titanic['AgeGroup_cut_2'] = pd.cut(titanic["Age"], bins, labels = labels)

# %%
sns.barplot(y="AgeGroup_cut_2", x='Survived', data=titanic, palette="flare")

# %% [markdown]
# ## Histplot

# %%
# Para poder representar gráficamente un histograma bins=default
sns.histplot(x=titanic.Age)

# %%
sns.histplot(x=titanic.Age, bins=5)

# %%
sns.histplot(x=titanic.Age, binwidth=10)

# %%
sns.histplot(x=titanic.Age, kde=True) # permite ver la aproximación de la distribución

# %%
sns.histplot(x=titanic.Age, element='step') # añadir pasos

# %%
sns.histplot(x=titanic.Age, element='step', fill=False) # quitamos el relleno

# %%
penguins.body_mass_g.describe()
# Out:
# count     342.000000
# mean     4201.754386
# std       801.954536
# min      2700.000000
# 25%      3550.000000
# 50%      4050.000000
# 75%      4750.000000
# max      6300.000000
# Name: body_mass_g, dtype: float64

# %%
sns.histplot(x=penguins.body_mass_g)

# %%
sns.histplot(x=penguins[penguins.species == 'Adelie'].body_mass_g) # podemos aplicar filtros

# %%
sns.histplot(x=titanic.Age, hue=titanic.Sex, element='step')

# %%
sns.histplot(x=penguins.body_mass_g, hue=penguins.species, element='step')

# %%
sns.histplot(x=penguins.body_mass_g, hue=penguins.species, element="step", multiple="fill") # relleno multiple

# %% [markdown]
# ## Kdeplot
#
# muy útil para una variable numèrica, es similar al histograma pero sin mostrar las barras.

# %%
sns.kdeplot(x=titanic.Age, hue=titanic.Pclass)

# %%
sns.kdeplot(x=penguins.body_mass_g, hue=penguins.species)

# %% [markdown]
# ## Scatterplot
#
# muy útil para 2 variables numéricas

# %%
# cuando realizamos una matriz de correlaciones
penguins.corr()
# Out:
#                    bill_length_mm  ...  body_mass_g
# bill_length_mm           1.000000  ...     0.595110
# bill_depth_mm           -0.235053  ...    -0.471916
# flipper_length_mm        0.656181  ...     0.871202
# body_mass_g              0.595110  ...     1.000000
#
# [4 rows x 4 columns]

# %%
# mostramos gráficamente dos variables numéricas
sns.scatterplot(x='body_mass_g', y='flipper_length_mm', data=penguins) # mostrará una correlación fuerte

# %%
sns.scatterplot(x='body_mass_g', y='flipper_length_mm', hue='species', data=penguins) # mostrará una correlación fuerte

# %%
sns.scatterplot(x='body_mass_g', y='bill_length_mm', data=penguins) # muestra una correlación normal

# %%
sns.scatterplot(x='bill_length_mm', y='bill_depth_mm', data=penguins) # no muestra ninguna correlación

# %%
# aplicando a este último el parámetro hue, podemos observar los segmentos por especie
sns.scatterplot(x='bill_length_mm', y='bill_depth_mm', hue='species', data=penguins)

# %%
sns.scatterplot(x='bill_length_mm', y='bill_depth_mm', hue='sex', data=penguins)

# %%
# Utilizamos el style para marcar las zonas
# %matplotlib notebook
# %matplotlib inline
sns.scatterplot(x="bill_length_mm", y="bill_depth_mm", style="island", data=penguins)

# %%
sns.scatterplot(x="bill_length_mm", y="bill_depth_mm", hue="species", style="island", data=penguins)

# %% [markdown]
# ## Jointplot
#
# útil para 2 variables numèricas

# %%
sns.jointplot(x='bill_length_mm', y='bill_depth_mm', data=penguins)

# %%
sns.jointplot(data=penguins, x="bill_length_mm", y="bill_depth_mm", hue="species")

# %% [markdown]
# ## Pairplot
#
# muy útil cuando necesitamos comparar diferentes variables

# %%
sns.pairplot(data=penguins, plot_kws={'size':1})

# %% [markdown]
# ## Boxplot
#
# útil para variables numéricas.
# Representación de los valores máximo y mínimo (100% y el 0%), además de la mediana, 50%, 75%, 25%

# %%
sns.boxplot(y='Age', data=titanic)

# %%
titanic.Age.describe()
# Out:
# count    891.000000
# mean      23.699966
# std       17.731181
# min       -0.500000
# 25%        6.000000
# 50%       24.000000
# 75%       35.000000
# max       80.000000
# Name: Age, dtype: float64

# %%
np.median(titanic.Age)
# Out:
# 24.0

# %%
q1 = titanic.Age.quantile(.25)
q1
# Out:
# 6.0

# %%
q3 = titanic.Age.quantile(.75)
q3
# Out:
# 35.0

# %%
q2 = titanic.Age.quantile(.50)
q2
# Out:
# 24.0

# %%
# calculamos el rango intercuantil
iqr = q3 - q1
iqr
# Out:
# 29.0

# %%
sns.boxplot(x="Pclass", y="Age", data=titanic)

# %%
sns.boxplot(x="species", y="body_mass_g", data=penguins)

# %% [markdown]
# ## Pie Chart

# %%
labels = ['Vegetarians', 'Non-Vegetarians', 'Vegans', 'Crudivegans']
sizes = [40, 45, 10, 5]

plt.pie(sizes, labels=labels)
plt.axis('equal')
plt.show()

# %% [markdown]
# ## Facet Grid

# %%
g = sns.FacetGrid(data=penguins, col="island")
g.map_dataframe(sns.histplot, x="body_mass_g", element="step")

# %%
g = sns.FacetGrid(data=penguins, col="island", row="species")
g.map_dataframe(sns.histplot, x="body_mass_g")

# %%
g = sns.FacetGrid(data=titanic, col="Sex", row="Pclass", sharex=False)
g.map_dataframe(sns.countplot, x="Survived", palette="Reds")

# %%
sns_plot = sns.countplot(x=titanic.Pclass, hue=titanic.Sex, palette="Greens")

# %%
# Si queremos guardar las imagenes y utilizando el parámetro dpi para que podamos definir la resolución
sns_plot.figure.savefig('class_and_gender10.jpg', dpi=10)

# %%
sns_plot.figure.savefig('class_and_gender100.jpg', dpi=100)

# %%
sns_plot.figure.savefig('class_and_gender1000.jpg', dpi=1000)

# %%
sns_plot.figure.savefig('class_and_gender3000.jpg', dpi=3000)
